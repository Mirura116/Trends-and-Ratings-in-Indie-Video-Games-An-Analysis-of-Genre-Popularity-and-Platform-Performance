# %%
import pandas as pd

pd.read_csv('games-features.csv')
# Out:
#        index  QueryID  ResponseID                  QueryName  \
# 0          0       10          10             Counter-Strike
# 1          1       20          20      Team Fortress Classic
# 2          2       30          30              Day of Defeat
# 3          3       40          40         Deathmatch Classic
# 4          4       50          50  Half-Life: Opposing Force
# ...      ...      ...         ...                        ...
# 13352  13352   567660      567660              Baseball Riot
# 13353  13353   567860      567860                  Passage 4
# 13354  13354   567940      567940                 Piximalism
# 13355  13355   568150      568150                 Technoball
# 13356  13356   559250      559250           Ghostlight Manor
#
#                     ResponseName  ReleaseDate  RequiredAge  DemoCount  \
# 0                 Counter-Strike   Nov 1 2000            0          0
# 1          Team Fortress Classic   Apr 1 1999            0          0
# ...
